# %%
import glob
import pandas as pd

# %%
txtfiles = []
for file in glob.glob("*.h5"):
    txtfiles.append(file)

# %%
len(txtfiles)
# Out:
# 500

# %%
company=pd.read_csv('/home/jay/company.csv')

# %%
company
# Out:
#     symbol                     company_name                  sector
# 0      MMM                       3M Company             Industrials
# 1      AOS                  A.O. Smith Corp             Industrials
# 2      ABT              Abbott Laboratories             Health Care
# 3     ABBV                      AbbVie Inc.             Health Care
# 4     ABMD                      ABIOMED Inc             Health Care
# 5      ACN                    Accenture plc  Information Technology
# 6     ATVI              Activision Blizzard  Communication Services
# 7     ADBE                       Adobe Inc.  Information Technology
# 8      AAP               Advance Auto Parts  Consumer Discretionary
# 9      AMD       Advanced Micro Devices Inc  Information Technology
# 10     AES                         AES Corp               Utilities
# 11     AFL                        AFLAC Inc              Financials
# 12       A         Agilent Technologies Inc             Health Care
# 13     APD     Air Products & Chemicals Inc               Materials
# 14    AKAM          Akamai Technologies Inc  Information Technology
# 15     ALK             Alaska Air Group Inc             Industrials
# 16     ALB                   Albemarle Corp               Materials
# 17     ARE  Alexandria Real Estate Equities             Real Estate
# 18    ALXN          Alexion Pharmaceuticals             Health Care
# 19    ALGN                 Align Technology             Health Care
# 20    ALLE                         Allegion             Industrials
# 21     ADS            Alliance Data Systems  Information Technology
# 22     LNT              Alliant Energy Corp               Utilities
# 23     ALL                    Allstate Corp              Financials
# 24   GOOGL          Alphabet Inc. (Class A)  Communication Services
# 25    GOOG          Alphabet Inc. (Class C)  Communication Services
# 26      MO                 Altria Group Inc        Consumer Staples
# 27    AMZN                  Amazon.com Inc.  Consumer Discretionary
# 28    AMCR                        Amcor plc               Materials
# 29     AEE                      Ameren Corp               Utilities
# ..     ...                              ...                     ...
# 475      V                        Visa Inc.  Information Technology
# 476    VNO             Vornado Realty Trust             Real Estate
# 477    VMC                 Vulcan Materials               Materials
# 478    WRB        W. R. Berkley Corporation              Financials
# 479    WAB               Wabtec Corporation             Industrials
# 480    WBA         Walgreens Boots Alliance        Consumer Staples
# 481    WMT                          Walmart        Consumer Staples
# 482     WM            Waste Management Inc.             Industrials
# 483    WAT               Waters Corporation             Health Care
# 484    WEC                 WEC Energy Group               Utilities
# 485    WFC                      Wells Fargo              Financials
# 486   WELL                   Welltower Inc.             Real Estate
# 487    WST     West Pharmaceutical Services             Health Care
# 488    WDC                  Western Digital  Information Technology
# 489     WU                 Western Union Co  Information Technology
# 490    WRK                         WestRock               Materials
# 491     WY                     Weyerhaeuser             Real Estate
# 492    WHR                  Whirlpool Corp.  Consumer Discretionary
# 493    WMB                    Williams Cos.                  Energy
# 494   WLTW             Willis Towers Watson              Financials
# 495   WYNN                 Wynn Resorts Ltd  Consumer Discretionary
# 496    XEL                  Xcel Energy Inc               Utilities
# 497    XRX                            Xerox  Information Technology
# 498   XLNX                           Xilinx  Information Technology
# 499    XYL                       Xylem Inc.             Industrials
# 500    YUM                  Yum! Brands Inc  Consumer Discretionary
# 501   ZBRA               Zebra Technologies  Information Technology
# 502    ZBH           Zimmer Biomet Holdings             Health Care
# 503   ZION                    Zions Bancorp              Financials
# 504    ZTS                           Zoetis             Health Care
#
# [505 rows x 3 columns]

# %%
company_name=company['symbol']

# %%
str_=".h5"
company_name_new=[]
for name in company_name:
    name=name+str_
    company_name_new.append(name)

# %%
company_name_new
# Out:
# ['MMM.h5',
#  'AOS.h5',
#  'ABT.h5',
#  'ABBV.h5',
#  'ABMD.h5',
#  'ACN.h5',
#  'ATVI.h5',
#  'ADBE.h5',
#  'AAP.h5',
#  'AMD.h5',
#  'AES.h5',
#  'AFL.h5',
#  'A.h5',
#  'APD.h5',
#  'AKAM.h5',
#  'ALK.h5',
#  'ALB.h5',
#  'ARE.h5',
#  'ALXN.h5',
#  'ALGN.h5',
#  'ALLE.h5',
#  'ADS.h5',
#  'LNT.h5',
#  'ALL.h5',
#  'GOOGL.h5',
#  'GOOG.h5',
#  'MO.h5',
#  'AMZN.h5',
#  'AMCR.h5',
#  'AEE.h5',
#  'AAL.h5',
#  'AEP.h5',
#  'AXP.h5',
#  'AIG.h5',
#  'AMT.h5',
#  'AWK.h5',
#  'AMP.h5',
#  'ABC.h5',
#  'AME.h5',
#  'AMGN.h5',
#  'APH.h5',
#  'ADI.h5',
#  'ANSS.h5',
#  'ANTM.h5',
#  'AON.h5',
#  'APA.h5',
#  'AIV.h5',
#  'AAPL.h5',
#  'AMAT.h5',
#  'APTV.h5',
#  'ADM.h5',
#  'ANET.h5',
#  'AJG.h5',
#  'AIZ.h5',
#  'T.h5',
#  'ATO.h5',
#  'ADSK.h5',
#  'ADP.h5',
#  'AZO.h5',
#  'AVB.h5',
#  'AVY.h5',
#  'BKR.h5',
#  'BLL.h5',
#  'BAC.h5',
#  'BAX.h5',
#  'BDX.h5',
#  'BRK.B.h5',
#  'BBY.h5',
#  'BIIB.h5',
#  'BLK.h5',
#  'BA.h5',
#  'BKNG.h5',
#  'BWA.h5',
#  'BXP.h5',
#  'BSX.h5',
#  'BMY.h5',
#  'AVGO.h5',
#  'BR.h5',
#  'BF.B.h5',
#  'CHRW.h5',
#  'COG.h5',
#  'CDNS.h5',
#  'CPB.h5',
#  'COF.h5',
#  'CAH.h5',
#  'KMX.h5',
#  'CCL.h5',
#  'CARR.h5',
#  'CAT.h5',
#  'CBOE.h5',
#  'CBRE.h5',
#  'CDW.h5',
#  'CE.h5',
#  'CNC.h5',
#  'CNP.h5',
#  'CTL.h5',
#  'CERN.h5',
#  'CF.h5',
#  'SCHW.h5',
#  'CHTR.h5',
#  'CVX.h5',
#  'CMG.h5',
#  'CB.h5',
#  'CHD.h5',
#  'CI.h5',
#  'CINF.h5',
#  'CTAS.h5',
#  'CSCO.h5',
#  'C.h5',
#  'CFG.h5',
#  'CTXS.h5',
#  'CME.h5',
#  'CMS.h5',
#  'KO.h5',
#  'CTSH.h5',
#  'CL.h5',
#  'CMCSA.h5',
#  'CMA.h5',
#  'CAG.h5',
#  'CXO.h5',
#  'COP.h5',
#  'ED.h5',
#  'STZ.h5',
#  'CPRT.h5',
#  'GLW.h5',
#  'CTVA.h5',
#  'COST.h5',
#  'COTY.h5',
#  'CCI.h5',
#  'CSX.h5',
#  'CMI.h5',
#  'CVS.h5',
#  'DHI.h5',
#  'DHR.h5',
#  'DRI.h5',
#  'DVA.h5',
#  'DE.h5',
#  'DAL.h5',
#  'XRAY.h5',
#  'DVN.h5',
#  'DXCM.h5',
#  'FANG.h5',
#  'DLR.h5',
#  'DFS.h5',
#  'DISCA.h5',
#  'DISCK.h5',
#  'DISH.h5',
#  'DG.h5',
#  'DLTR.h5',
#  'D.h5',
#  'DPZ.h5',
#  'DOV.h5',
#  'DOW.h5',
#  'DTE.h5',
#  'DUK.h5',
#  'DRE.h5',
#  'DD.h5',
#  'DXC.h5',
#  'ETFC.h5',
#  'EMN.h5',
#  'ETN.h5',
#  'EBAY.h5',
#  'ECL.h5',
#  'EIX.h5',
#  'EW.h5',
#  'EA.h5',
#  'EMR.h5',
#  'ETR.h5',
#  'EOG.h5',
#  'EFX.h5',
#  'EQIX.h5',
#  'EQR.h5',
#  'ESS.h5',
#  'EL.h5',
#  'RE.h5',
#  'EVRG.h5',
#  'ES.h5',
#  'EXC.h5',
#  'EXPE.h5',
#  'EXPD.h5',
#  'EXR.h5',
#  'XOM.h5',
#  'FFIV.h5',
#  'FB.h5',
#  'FAST.h5',
#  'FRT.h5',
#  'FDX.h5',
#  'FIS.h5',
#  'FITB.h5',
#  'FRC.h5',
#  'FE.h5',
#  'FISV.h5',
#  'FLT.h5',
#  'FLIR.h5',
#  'FLS.h5',
#  'FMC.h5',
#  'F.h5',
#  'FTNT.h5',
#  'FTV.h5',
#  'FBHS.h5',
#  'FOXA.h5',
#  'FOX.h5',
#  'BEN.h5',
#  'FCX.h5',
#  'GPS.h5',
#  'GRMN.h5',
#  'IT.h5',
#  'GD.h5',
#  'GE.h5',
#  'GIS.h5',
#  'GM.h5',
#  'GPC.h5',
#  'GILD.h5',
#  'GPN.h5',
#  'GL.h5',
#  'GS.h5',
#  'GWW.h5',
#  'HRB.h5',
#  'HAL.h5',
#  'HBI.h5',
#  'HOG.h5',
#  'HIG.h5',
#  'HAS.h5',
#  'HCA.h5',
#  'PEAK.h5',
#  'HSIC.h5',
#  'HES.h5',
#  'HPE.h5',
#  'HLT.h5',
#  'HFC.h5',
#  'HOLX.h5',
#  'HD.h5',
#  'HON.h5',
#  'HRL.h5',
#  'HST.h5',
#  'HWM.h5',
#  'HPQ.h5',
#  'HUM.h5',
#  'HBAN.h5',
#  'HII.h5',
#  'IEX.h5',
#  'IDXX.h5',
#  'INFO.h5',
#  'ITW.h5',
#  'ILMN.h5',
#  'INCY.h5',
#  'IR.h5',
#  'INTC.h5',
#  'ICE.h5',
#  'IBM.h5',
#  'IP.h5',
#  'IPG.h5',
#  'IFF.h5',
#  'INTU.h5',
#  'ISRG.h5',
#  'IVZ.h5',
#  'IPGP.h5',
#  'IQV.h5',
#  'IRM.h5',
#  'JBHT.h5',
#  'JKHY.h5',
#  'J.h5',
#  'SJM.h5',
#  'JNJ.h5',
#  'JCI.h5',
#  'JPM.h5',
#  'JNPR.h5',
#  'KSU.h5',
#  'K.h5',
#  'KEY.h5',
#  'KEYS.h5',
#  'KMB.h5',
#  'KIM.h5',
#  'KMI.h5',
#  'KLAC.h5',
#  'KSS.h5',
#  'KHC.h5',
#  'KR.h5',
#  'LB.h5',
#  'LHX.h5',
#  'LH.h5',
#  'LRCX.h5',
#  'LW.h5',
#  'LVS.h5',
#  'LEG.h5',
#  'LDOS.h5',
#  'LEN.h5',
#  'LLY.h5',
#  'LNC.h5',
#  'LIN.h5',
#  'LYV.h5',
#  'LKQ.h5',
#  'LMT.h5',
#  'L.h5',
#  'LOW.h5',
#  'LYB.h5',
#  'MTB.h5',
#  'MRO.h5',
#  'MPC.h5',
#  'MKTX.h5',
#  'MAR.h5',
#  'MMC.h5',
#  'MLM.h5',
#  'MAS.h5',
#  'MA.h5',
#  'MXIM.h5',
#  'MKC.h5',
#  'MCD.h5',
#  'MCK.h5',
#  'MDT.h5',
#  'MRK.h5',
#  'MET.h5',
#  'MTD.h5',
#  'MGM.h5',
#  'MCHP.h5',
#  'MU.h5',
#  'MSFT.h5',
#  'MAA.h5',
#  'MHK.h5',
#  'TAP.h5',
#  'MDLZ.h5',
#  'MNST.h5',
#  'MCO.h5',
#  'MS.h5',
#  'MSI.h5',
#  'MSCI.h5',
#  'MYL.h5',
#  'NDAQ.h5',
#  'NOV.h5',
#  'NTAP.h5',
#  'NFLX.h5',
#  'NWL.h5',
#  'NEM.h5',
#  'NWSA.h5',
#  'NWS.h5',
#  'NEE.h5',
#  'NLSN.h5',
#  'NKE.h5',
#  'NI.h5',
#  'NBL.h5',
#  'JWN.h5',
#  'NSC.h5',
#  'NTRS.h5',
#  'NOC.h5',
#  'NLOK.h5',
#  'NCLH.h5',
#  'NRG.h5',
#  'NUE.h5',
#  'NVDA.h5',
#  'NVR.h5',
#  'ORLY.h5',
#  'OXY.h5',
#  'ODFL.h5',
#  'OMC.h5',
#  'OKE.h5',
#  'ORCL.h5',
#  'OTIS.h5',
#  'PCAR.h5',
#  'PKG.h5',
#  'PH.h5',
#  'PAYX.h5',
#  'PAYC.h5',
#  'PYPL.h5',
#  'PNR.h5',
#  'PBCT.h5',
#  'PEP.h5',
#  'PKI.h5',
#  'PRGO.h5',
#  'PFE.h5',
#  'PM.h5',
#  'PSX.h5',
#  'PNW.h5',
#  'PXD.h5',
#  'PNC.h5',
#  'PPG.h5',
#  'PPL.h5',
#  'PFG.h5',
#  'PG.h5',
#  'PGR.h5',
#  'PLD.h5',
#  'PRU.h5',
#  'PEG.h5',
#  'PSA.h5',
#  'PHM.h5',
#  'PVH.h5',
#  'QRVO.h5',
#  'QCOM.h5',
#  'PWR.h5',
#  'DGX.h5',
#  'RL.h5',
#  'RJF.h5',
#  'RTX.h5',
#  'O.h5',
#  'REG.h5',
#  'REGN.h5',
#  'RF.h5',
#  'RSG.h5',
#  'RMD.h5',
#  'RHI.h5',
#  'ROK.h5',
#  'ROL.h5',
#  'ROP.h5',
#  'ROST.h5',
#  'RCL.h5',
#  'SPGI.h5',
#  'CRM.h5',
#  'SBAC.h5',
#  'SLB.h5',
#  'STX.h5',
#  'SEE.h5',
#  'SRE.h5',
#  'NOW.h5',
#  'SHW.h5',
#  'SPG.h5',
#  'SWKS.h5',
#  'SLG.h5',
#  'SNA.h5',
#  'SO.h5',
#  'LUV.h5',
#  'SWK.h5',
#  'SBUX.h5',
#  'STT.h5',
#  'STE.h5',
#  'SYK.h5',
#  'SIVB.h5',
#  'SYF.h5',
#  'SNPS.h5',
#  'SYY.h5',
#  'TMUS.h5',
#  'TROW.h5',
#  'TTWO.h5',
#  'TPR.h5',
#  'TGT.h5',
#  'TEL.h5',
#  'FTI.h5',
#  'TFX.h5',
#  'TXN.h5',
#  'TXT.h5',
#  'BK.h5',
#  'CLX.h5',
#  'COO.h5',
#  'HSY.h5',
#  'MOS.h5',
#  'TRV.h5',
#  'DIS.h5',
#  'TMO.h5',
#  'TIF.h5',
#  'TJX.h5',
#  'TSCO.h5',
#  'TT.h5',
#  'TDG.h5',
#  'TFC.h5',
#  'TWTR.h5',
#  'TSN.h5',
#  'USB.h5',
#  'UDR.h5',
#  'ULTA.h5',
#  'UAA.h5',
#  'UA.h5',
#  'UNP.h5',
#  'UAL.h5',
#  'UNH.h5',
#  'UPS.h5',
#  'URI.h5',
#  'UHS.h5',
#  'UNM.h5',
#  'VFC.h5',
#  'VLO.h5',
#  'VAR.h5',
#  'VTR.h5',
#  'VRSN.h5',
#  'VRSK.h5',
#  'VZ.h5',
#  'VRTX.h5',
#  'VIAC.h5',
#  'V.h5',
#  'VNO.h5',
#  'VMC.h5',
#  'WRB.h5',
#  'WAB.h5',
#  'WBA.h5',
#  'WMT.h5',
#  'WM.h5',
#  'WAT.h5',
#  'WEC.h5',
#  'WFC.h5',
#  'WELL.h5',
#  'WST.h5',
#  'WDC.h5',
#  'WU.h5',
#  'WRK.h5',
#  'WY.h5',
#  'WHR.h5',
#  'WMB.h5',
#  'WLTW.h5',
#  'WYNN.h5',
#  'XEL.h5',
#  'XRX.h5',
#  'XLNX.h5',
#  'XYL.h5',
#  'YUM.h5',
#  'ZBRA.h5',
#  'ZBH.h5',
#  'ZION.h5',
#  'ZTS.h5']

# %%
len(set(company_name_new).union(txtfiles))
# Out:
# 506

# %%
indices=[]

# %%
indices=set(company_name_new)-set(txtfiles)

# %%
set(indices)
# Out:
# {'BF.B.h5', 'BRK.B.h5', 'CARR.h5', 'HSY.h5', 'OTIS.h5', 'XRX.h5'}

# %%
element=""
for i in range(len(indices_list)) :
    element=indices_list[i]
    new_element=element.strip(".h5")
    indices_new.append(new_element)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4b8895ede579> in <module>
#       1 element=""
# ----> 2 for i in range(len(indices_list)) :
#       3     element=indices_list[i]
#       4     new_element=element.strip(".h5")
#       5     indices_new.append(new_element)
#
# NameError: name 'indices_list' is not defined

# %%
len(indices_new)
# Out:
# 16

# %%
indices_list=list(indices)

# %%
type(indices_list)
# Out:
# list

# %%
indices_new=[]

# %%
new_company=pd.DataFrame(indices_new)

# %%
new_company.to_csv('new_company.csv')
